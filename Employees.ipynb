# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_excel('Employees.xlsx')
df
# Out:
#       No   First Name Last Name  Gender Start Date  Years  \
# 0      1       Ghadir     Hmshw    Male 2018-04-04      2
# 1      2         Omar    Hishan    Male 2020-05-21      0
# 2      3        Ailya    Sharaf  Female 2017-09-28      3
# 3      4         Lwiy     Qbany    Male 2018-08-14      2
# 4      5        Ahmad     Bikri    Male 2020-03-11      0
# ..   ...          ...       ...     ...        ...    ...
# 684  685         Sari     Hanna    Male 2020-05-26      0
# 685  686      Eubayda      Kayd    Male 2020-06-03      0
# 686  687       Khalil    Alkalu    Male 2017-07-11      3
# 687  688      Muhamad    Shrbjy    Male 2018-05-30      2
# 688  689  Abd Albasit   AlAhmar    Male 2020-08-05      0
#
#                  Department               Country Center  Monthly Salary  \
# 0           Quality Control                 Egypt   West            1560
# 1           Quality Control          Saudi Arabia   West            3247
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Years           689 non-null    int64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    int64
#  11  Job Rate        689 non-null    float64
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(6)
# memory usage: 80.9+ KB

# %% [markdown]
# # UniVariate Analysis

# %% [markdown]
# ### Gender Column

# %%
count=df.Gender.value_counts()

# %%
sns.barplot(x=['Male','Female'],y=count, palette=sns.color_palette("Paired"))
plt.title('Gender Type')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\George Hany\AppData\Local\Temp\ipykernel_45644\324061824.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Male','Female'],y=count, palette=sns.color_palette("Paired"))
# C:\Users\George Hany\AppData\Local\Temp\ipykernel_45644\324061824.py:1: UserWarning: The palette list has more values (12) than needed (2), which may not be intended.
#   sns.barplot(x=['Male','Female'],y=count, palette=sns.color_palette("Paired"))

# %% [markdown]
# - **Males who work in this company are more than females**

# %% [markdown]
# ### Years Column

# %%
count= df.Years.value_counts()
count
# Out:
# Years
# 1    246
# 2    155
# 0    153
# 3     81
# 4     52
# 5      2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(df,x='Years', palette='husl',hue='Years',legend=False)
plt.title('Years Of Work')
plt.xlabel('Years')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Most Employees have low Years of Experience which may conclude that the company tends to hire new heads**

# %% [markdown]
# ### Department Column

# %%
count=df.Department.value_counts()
count
# Out:
# Department
# Manufacturing                  140
# Quality Control                 89
# Account Management              84
# Quality Assurance               67
# Facilities/Engineering          58
# Marketing                       48
# IT                              40
# Product Development             34
# Sales                           20
# Creative                        19
# Training                        16
# Professional Training Group     14
# Environmental Compliance        13
# Environmental Health/Safety      9
# Major Mfg Projects               8
# Green Building                   8
# Human Resources                  7
# Manufacturing Admin              5
# Research/Development             5
# Research Center                  5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(df,x='Department', palette='husl',hue='Department',legend=False)
plt.title('Department Table')
plt.xlabel('Departments')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - **Most Employees work in Major Mfg Projects then Quality Control and Quality assurance which may say most employees needed in Management**

# %% [markdown]
# ### Country Column

# %%
counts=df.Country.value_counts()
counts
# Out:
# Country
# Egypt                   379
# United Arab Emirates    156
# Saudi Arabia             90
# Syria                    53
# Lebanon                  11
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(df,x='Country', palette='husl',hue='Country',legend=False)
plt.title('Country Table')
plt.xlabel('Country')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# - **Most Employees from this Company are From Egypt**

# %% [markdown]
# ### Center Column

# %%
count=df.Center.value_counts()
count
# Out:
# Center
# Main     251
# North    207
# West     119
# South     65
# East      47
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(df,x='Center')
plt.title('Center Distribution')
plt.xlabel('Center')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Most Center Branches are from Main and then North**

# %% [markdown]
# ### Monthly Salary Column

# %%
df['Monthly Salary'].describe()
# Out:
# count     689.000000
# mean     2068.201742
# std       763.289240
# min       703.000000
# 25%      1436.000000
# 50%      2077.000000
# 75%      2682.000000
# max      3450.000000
# Name: Monthly Salary, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Monthly Salary',bins=15)
plt.xlabel('Monthly Salary')
plt.title("Monthly Salary Table")
plt.ylabel("Frequency")
plt.show()

# %%
month_df=df[df['Monthly Salary']>2000]
month_df
# Out:
#       No   First Name Last Name  Gender Start Date  Years  \
# 1      2         Omar    Hishan    Male 2020-05-21      0
# 2      3        Ailya    Sharaf  Female 2017-09-28      3
# 5      6      Muhamad    Zueitr    Male 2016-02-02      4
# 7      8      Muhamad     Alaya    Male 2018-02-10      2
# 11    12      Muhamad       Iad    Male 2018-07-19      2
# ..   ...          ...       ...     ...        ...    ...
# 683  684          Asd   Bwfaeur    Male 2017-06-27      3
# 685  686      Eubayda      Kayd    Male 2020-06-03      0
# 686  687       Khalil    Alkalu    Male 2017-07-11      3
# 687  688      Muhamad    Shrbjy    Male 2018-05-30      2
# 688  689  Abd Albasit   AlAhmar    Male 2020-08-05      0
#
#                  Department               Country Center  Monthly Salary  \
# 1           Quality Control          Saudi Arabia   West            3247
# 2        Major Mfg Projects          Saudi Arabia   West            2506
# ...

# %% [markdown]
# - **Most Employees Monthly Salary averages 2000**

# %% [markdown]
# ### Annual Salaries

# %%
df['Annual Salary'].describe()
# Out:
# count      689.000000
# mean     24818.420900
# std       9159.470878
# min       8436.000000
# 25%      17232.000000
# 50%      24924.000000
# 75%      32184.000000
# max      41400.000000
# Name: Annual Salary, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Annual Salary',bins=15)
plt.xlabel('Annual Salary')
plt.title("Annual Salary Table")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - **Most Annual Salaries averages in between 25000**

# %% [markdown]
# ### Job Rate Column

# %%
df['Job Rate'].value_counts()
# Out:
# Job Rate
# 5.0    215
# 3.0    208
# 4.5    124
# 2.0     72
# 1.0     70
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(df,x='Job Rate', palette='husl',hue='Job Rate',legend=False)
plt.title('Job Rate Table')
plt.xlabel('Job Rating')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# - **Most Ratings are 5 and 3**

# %% [markdown]
# ### Sick Leaves Column

# %%
df['Sick Leaves'].value_counts()
# Out:
# Sick Leaves
# 0    370
# 1     87
# 6     82
# 5     40
# 2     37
# 4     37
# 3     36
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(df,x='Sick Leaves', palette='husl',hue='Sick Leaves',legend=False)
plt.title('Sick Leaves Table')
plt.xlabel('Leaves')
plt.ylabel('Frequency')

plt.show()

# %%
df[df['Sick Leaves']>5]
# Out:
#       No First Name  Last Name  Gender Start Date  Years  \
# 6      7        Iin  Alhalaliu  Female 2020-05-08      0
# 12    13     Razaan      Nasif  Female 2018-11-11      2
# 19    20      Ayham    Tutwnji    Male 2019-10-02      1
# 24    25    Muhamad    Altarah    Male 2020-12-13      0
# 35    36    Muhamad     Aleass    Male 2019-09-23      1
# ..   ...        ...        ...     ...        ...    ...
# 652  653    Muhamad      Ratib    Male 2019-11-24      1
# 664  665    Muhamad    Almisri    Male 2020-11-06      0
# 669  670      Dania    Earmush  Female 2019-12-01      1
# 671  672      Jihan      Nadir  Female 2019-04-18      1
# 677  678      Amjad      Nasir    Male 2019-03-14      1
#
#                  Department               Country Center  Monthly Salary  \
# 6                     Sales  United Arab Emirates   Main            1959
# 12   Facilities/Engineering                 Egypt   Main            1999
# ...

# %% [markdown]
# - **Most Employees did not take their sick leaves by far**

# %% [markdown]
# ### Unpaid Leaves Column

# %%
df['Unpaid Leaves'].value_counts()
# Out:
# Unpaid Leaves
# 0    541
# 4     30
# 5     29
# 1     26
# 3     22
# 6     21
# 2     20
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(df,x='Unpaid Leaves', palette='husl',hue='Unpaid Leaves',legend=False)
plt.title('Unpaid Leaves Table')
plt.xlabel('Unpaid Leaves Times')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# - **Most Employees did not leave unpaid leaves while all the other times are averging the same number of Employees**

# %% [markdown]
# ### Overtime Hours Column

# %%
df['Overtime Hours'].describe()
# Out:
# count    689.000000
# mean      13.702467
# std       25.692049
# min        0.000000
# 25%        3.000000
# 50%        7.000000
# 75%       10.000000
# max      198.000000
# Name: Overtime Hours, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Overtime Hours',bins=15)
plt.xlabel('Overtime Hours')
plt.title("Overtime Hours Table")
plt.ylabel("Frequency")
plt.show()

# %%
Q1= df['Overtime Hours'].quantile(0.25)
Q3=df['Overtime Hours'].quantile(0.75)

IQR=Q3-Q1
upper=Q3 + 1.5*IQR
Lower=Q1 - 1.5*IQR

print(upper)
print(Lower)
# Out:
# 20.5
# -7.5

# %%
plt.figure(figsize=(10,6))

sns.histplot(df['Overtime Hours'])
plt.title('Overtime Hours Distribution')
plt.xlabel('Overtime Hours')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(data=df,x='Overtime Hours')
plt.show()

# %%
not_outlier_df=df[(df['Overtime Hours']>Lower)&(df['Overtime Hours']<upper)]
not_outlier_df
# Out:
#       No   First Name Last Name  Gender Start Date  Years  \
# 3      4         Lwiy     Qbany    Male 2018-08-14      2
# 5      6      Muhamad    Zueitr    Male 2016-02-02      4
# 7      8      Muhamad     Alaya    Male 2018-02-10      2
# 10    11      Muhamad   Alqadah    Male 2018-01-16      2
# 13    14       Iilian       Dbs  Female 2016-03-01      4
# ..   ...          ...       ...     ...        ...    ...
# 684  685         Sari     Hanna    Male 2020-05-26      0
# 685  686      Eubayda      Kayd    Male 2020-06-03      0
# 686  687       Khalil    Alkalu    Male 2017-07-11      3
# 687  688      Muhamad    Shrbjy    Male 2018-05-30      2
# 688  689  Abd Albasit   AlAhmar    Male 2020-08-05      0
#
#                  Department               Country Center  Monthly Salary  \
# 3             Manufacturing  United Arab Emirates   Main            1828
# 5       Product Development          Saudi Arabia  North            2332
# ...

# %% [markdown]
# - **Most Employees do their Overtime Hours are 0 to 20**

# %% [markdown]
# # BiVariate Analysis

# %%
df.groupby(['Gender'])['Monthly Salary'].mean()
# Out:
# Gender
# Female    2059.075000
# Male      2073.080178
# Name: Monthly Salary, dtype: float64

# %% [markdown]
# - Males and Females are equally Paid in this Company

# %%
df.groupby(['Gender'])['Sick Leaves'].value_counts()
# Out:
# Gender  Sick Leaves
# Female  0              133
#         1               35
#         2               16
#         6               16
#         5               15
#         4               13
#         3               12
# Male    0              237
#         6               66
#         1               52
#         5               25
#         3               24
#         4               24
#         2               21
# Name: count, dtype: int64

# %% [markdown]
# - Male Employees overall did not leave sick leaves but more men than women used their sick leaves

# %%
df.groupby(['Gender'])['Unpaid Leaves'].value_counts()
# Out:
# Gender  Unpaid Leaves
# Female  0                181
#         2                 12
#         1                 11
#         6                 11
#         4                 10
#         3                  8
#         5                  7
# Male    0                360
#         5                 22
#         4                 20
#         1                 15
#         3                 14
#         6                 10
#         2                  8
# Name: count, dtype: int64

# %% [markdown]
# - Male Employees overall did not leave unpaid leaves but more men than women used their unpaid leaves

# %%
df.groupby(['Gender'])['Job Rate'].mean()
# Out:
# Gender
# Female    3.591667
# Male      3.583519
# Name: Job Rate, dtype: float64

# %% [markdown]
# - Male and Female has the same Job rating

# %%
df.groupby(['Gender'])['Department'].describe()
# Out:
#        count unique            top freq
# Gender
# Female   240     19  Manufacturing   45
# Male     449     20  Manufacturing   95

# %%
df.groupby(['Gender'])['Years'].value_counts()
# Out:
# Gender  Years
# Female  1         88
#         2         55
#         0         46
#         3         29
#         4         22
# Male    1        158
#         0        107
#         2        100
#         3         52
#         4         30
#         5          2
# Name: count, dtype: int64

# %% [markdown]
# - There is no Female with 5 years of work and with ratio, Female has more years of experience overall

# %%
df.groupby(['Gender','Unpaid Leaves'])['Overtime Hours'].mean()
# Out:
# Gender  Unpaid Leaves
# Female  0                12.000000
#         1                21.454545
#         2                 7.166667
#         3                29.875000
#         4                 4.800000
#         5                16.000000
#         6                 5.909091
# Male    0                14.794444
#         1                11.933333
#         2                 6.500000
#         3                 7.500000
#         4                11.450000
#         5                22.136364
#         6                10.500000
# Name: Overtime Hours, dtype: float64

# %% [markdown]
# - Female tends to do overtime more than male in matter of unpaid leaves

# %%
df[df['Years']<3].groupby(['Years'])['Department'].value_counts()
# Out:
# Years  Department
# 0      Manufacturing                  28
#        Quality Control                22
#        Quality Assurance              21
#        Account Management             19
#        Facilities/Engineering         14
#        IT                             10
#        Marketing                      10
#        Product Development             6
#        Environmental Compliance        5
#        Training                        3
#        Creative                        2
#        Green Building                  2
#        Major Mfg Projects              2
#        Professional Training Group     2
#        Research/Development            2
#        Sales                           2
#        Environmental Health/Safety     1
#        Human Resources                 1
#        Manufacturing Admin             1
# 1      Manufacturing                  50
#        Account Management             30
#        Quality Control                29
# ...

# %% [markdown]
# - Most Employees who have the most years of work, work in Manufacturing

# %%
df.groupby(['Country'])['Monthly Salary'].mean()
# Out:
# Country
# Egypt                   2089.899736
# Lebanon                 1989.636364
# Saudi Arabia            2028.288889
# Syria                   2015.037736
# United Arab Emirates    2062.115385
# Name: Monthly Salary, dtype: float64

# %% [markdown]
# - All Employees from all countries get nearly the same Monthly Salary

# %%
df.groupby(['Department'])['Job Rate'].mean().head(5)
# Out:
# Department
# Account Management             3.690476
# Creative                       3.789474
# Environmental Compliance       3.076923
# Environmental Health/Safety    4.222222
# Facilities/Engineering         3.620690
# Name: Job Rate, dtype: float64

# %% [markdown]
# - Environmental Health/Safety are the best rated Department from all the Departments

# %%
df.groupby(['Country'])['Job Rate'].mean()
# Out:
# Country
# Egypt                   3.547493
# Lebanon                 3.272727
# Saudi Arabia            3.783333
# Syria                   3.481132
# United Arab Emirates    3.625000
# Name: Job Rate, dtype: float64

# %%
df[df['Country']=='Saudi Arabia'].groupby(['Country'])['Department'].value_counts()
# Out:
# Country       Department
# Saudi Arabia  Manufacturing                  20
#               Account Management             15
#               Quality Control                13
#               Quality Assurance               8
#               IT                              5
#               Marketing                       5
#               Professional Training Group     5
#               Facilities/Engineering          4
#               Sales                           4
#               Training                        3
#               Creative                        2
#               Green Building                  2
#               Product Development             2
#               Major Mfg Projects              1
#               Research Center                 1
# Name: count, dtype: int64

# %%
df[df['Country']=='United Arab Emirates'].groupby(['Country'])['Department'].value_counts()
# Out:
# Country               Department
# United Arab Emirates  Manufacturing                  29
#                       Account Management             20
#                       Quality Control                19
#                       Facilities/Engineering         16
#                       IT                             12
#                       Product Development            12
#                       Marketing                      11
#                       Quality Assurance               8
#                       Creative                        5
#                       Environmental Health/Safety     4
#                       Environmental Compliance        3
#                       Green Building                  3
#                       Human Resources                 3
#                       Professional Training Group     3
#                       Training                        3
#                       Research Center                 2
# ...

# %%
df[df['Country']=='Egypt'].groupby(['Country'])['Department'].value_counts()
# Out:
# Country  Department
# Egypt    Manufacturing                  78
#          Quality Control                52
#          Account Management             44
#          Quality Assurance              40
#          Facilities/Engineering         35
#          Marketing                      29
#          IT                             19
#          Product Development            15
#          Sales                          13
#          Creative                        9
#          Environmental Compliance        9
#          Training                        9
#          Environmental Health/Safety     5
#          Major Mfg Projects              5
#          Professional Training Group     5
#          Research/Development            5
#          Manufacturing Admin             3
#          Green Building                  2
#          Human Resources                 1
#          Research Center                 1
# Name: count, dtype: int64

# %% [markdown]
# - Saudi Arabian Employees has the highest Job Rate because they have small number of employees in each department

# %%
df.groupby(['Years'])['Monthly Salary'].mean()
# Out:
# Years
# 0    2166.712418
# 1    2046.784553
# 2    2025.141935
# 3    2031.456790
# 4    2052.519231
# 5    2399.500000
# Name: Monthly Salary, dtype: float64

# %% [markdown]
# - As the Years of Work increase the Monthly Salary increase

# %%
df.groupby(['Years'])['Annual Salary'].mean()
# Out:
# Years
# 0    26000.549020
# 1    24561.414634
# 2    24301.703226
# 3    24377.481481
# 4    24630.230769
# 5    28794.000000
# Name: Annual Salary, dtype: float64

# %%
df.groupby(['Center'])['Annual Salary'].mean()
# Out:
# Center
# East     27288.255319
# Main     24657.322709
# North    24777.739130
# South    23773.846154
# West     24824.067227
# Name: Annual Salary, dtype: float64

# %% [markdown]
# - East Center has the highest paid Center from all Centers

# %%
df[df['Unpaid Leaves']>0].groupby(['Unpaid Leaves'])['Overtime Hours'].mean()
# Out:
# Unpaid Leaves
# 1    15.961538
# 2     6.900000
# 3    15.636364
# 4     9.233333
# 5    20.655172
# 6     8.095238
# Name: Overtime Hours, dtype: float64

# %%
sns.scatterplot(x='Unpaid Leaves',y='Monthly Salary',data=df,hue='Overtime Hours')
plt.show()

# %% [markdown]
# - As the Unpaid Leaves Increase the monthly Salary decrease

# %%
sns.pairplot(df)
plt.show()

# %%
cm=df.corr(numeric_only=True)
sns.heatmap(cm,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# - There is no Correlation between values
